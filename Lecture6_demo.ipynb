# %% [markdown]
# <a href="https://colab.research.google.com/github/MHKhan18/colab-notebooks/blob/main/Lecture6_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We will look at an example of the transportation problem. There are street with blocks numbered 1 to n. Walking from s to s + 1 takes 1 minute. Taking a magic tram from s to 2s takes 2 minutes. How to travel from 1 to n in the least time?
#
# To formalize this problem, first we define the start state, successor and cost function.

# %%
class TransportationMDP(object):
    def __init__(self, N):
        # N = number of blocks
        self.N = N
    def startState(self):
        return 1
    def isEnd(self, state):
        return state == self.N
    def actions(self, state):
        # return list of valid actions
        result = []
        if state+1<=self.N:
            result.append('walk')
        if state*2<=self.N:
            result.append('tram')
        return result
    def succProbReward(self, state, action):
        # return list of (newState, prob, reward) triples
        # state = s, action = a, newState = s'
        # prob = T(s, a, s'), reward = Reward(s, a, s')
        result = []
        if action=='walk':
            result.append((state+1, 1., -1.))
        elif action=='tram':
            failProb = 0.5
            result.append((state*2, 1.-failProb, -2.))
            result.append((state, failProb, -2.))
        return result
    def discount(self):
        return 1.
    def states(self):
        return range(1, self.N+1)

# %%
# Inference (Algorithms)
import os
def valueIteration(mdp):
    # initialize
    V = {} # state -> Vopt[state]
    for state in mdp.states():
        V[state] = 0.

    def Q(state, action):
        return sum(prob*(reward + mdp.discount()*V[newState]) \
                for newState, prob, reward in mdp.succProbReward(state, action))

    while True:
        # compute the new values (newV) given the old values (V)
        newV = {}
        for state in mdp.states():
            if mdp.isEnd(state):
                newV[state] = 0.
            else:
                newV[state] = max(Q(state, action) for action in mdp.actions(state))
        # check for convergence
        if max(abs(V[state]-newV[state]) for state in mdp.states())<1e-10:
            break
        V = newV

        # read out policy
        pi = {}
        for state in mdp.states():
            if mdp.isEnd(state):
                pi[state] = 'none'
            else:
                pi[state] = max((Q(state, action), action) for action in mdp.actions(state))[1]

        # print stuff out
        os.system('clear')
        print('{:20} {:20} {:20}'.format('s', 'V(s)', 'pi(s)'))
        for state in mdp.states():
            print('{:20} {:20} {:20}'.format(state, V[state], pi[state]))
        input()

# %%
mdp = TransportationMDP(N=10)
#print(mdp.actions(3))
#print(mdp.succProbReward(3, 'walk'))
#print(mdp.succProbReward(3, 'tram'))
valueIteration(mdp)
# Out:
# s                    V(s)                 pi(s)
#                    1                 -1.0 walk
#                    2                 -1.0 walk
#                    3                 -1.0 walk
#                    4                 -1.0 walk
#                    5                 -1.0 walk
#                    6                 -1.0 walk
#                    7                 -1.0 walk
#                    8                 -1.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1                 -2.0 walk
#                    2                 -2.0 walk
#                    3                 -2.0 walk
#                    4                 -2.0 walk
#                    5                 -2.0 walk
#                    6                 -2.0 walk
#                    7                 -2.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1                 -3.0 walk
#                    2                 -3.0 walk
#                    3                 -3.0 walk
#                    4                 -3.0 walk
#                    5                 -3.0 tram
#                    6                 -3.0 walk
#                    7                 -3.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1                 -4.0 walk
#                    2                 -4.0 walk
#                    3                 -4.0 walk
#                    4                 -4.0 walk
#                    5                 -3.5 tram
#                    6                 -4.0 walk
#                    7                 -3.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1                 -5.0 walk
#                    2                 -5.0 walk
#                    3                 -5.0 walk
#                    4                 -4.5 walk
#                    5                -3.75 tram
#                    6                 -4.0 walk
#                    7                 -3.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1                 -6.0 walk
#                    2                 -6.0 walk
#                    3                 -5.5 walk
#                    4                -4.75 walk
#                    5               -3.875 tram
#                    6                 -4.0 walk
#                    7                 -3.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1                 -7.0 walk
#                    2                 -6.5 walk
#                    3                -5.75 walk
#                    4               -4.875 walk
#                    5              -3.9375 tram
#                    6                 -4.0 walk
#                    7                 -3.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1                 -7.5 walk
#                    2                -6.75 walk
#                    3               -5.875 walk
#                    4              -4.9375 walk
#                    5             -3.96875 tram
#                    6                 -4.0 walk
#                    7                 -3.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1                -7.75 walk
#                    2               -6.875 walk
#                    3              -5.9375 walk
#                    4             -4.96875 walk
#                    5            -3.984375 tram
#                    6                 -4.0 walk
#                    7                 -3.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1               -7.875 walk
#                    2              -6.9375 walk
#                    3             -5.96875 walk
#                    4            -4.984375 walk
#                    5           -3.9921875 tram
#                    6                 -4.0 walk
#                    7                 -3.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1              -7.9375 walk
#                    2             -6.96875 walk
#                    3            -5.984375 walk
#                    4           -4.9921875 walk
#                    5          -3.99609375 tram
#                    6                 -4.0 walk
#                    7                 -3.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1             -7.96875 walk
#                    2            -6.984375 walk
#                    3           -5.9921875 walk
#                    4          -4.99609375 walk
#                    5         -3.998046875 tram
#                    6                 -4.0 walk
#                    7                 -3.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
#
# s                    V(s)                 pi(s)
#                    1            -7.984375 walk
#                    2           -6.9921875 walk
#                    3          -5.99609375 walk
#                    4         -4.998046875 walk
#                    5        -3.9990234375 tram
#                    6                 -4.0 walk
#                    7                 -3.0 walk
#                    8                 -2.0 walk
#                    9                 -1.0 walk
#                   10                  0.0 none
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-b1b8dd1643bf> in <module>
#       3 #print(mdp.succProbReward(3, 'walk'))
#       4 #print(mdp.succProbReward(3, 'tram'))
# ----> 5 valueIteration(mdp)
#
# <ipython-input-24-4a6f574fdc2c> in valueIteration(mdp)
#      37         for state in mdp.states():
#      38             print('{:20} {:20} {:20}'.format(state, V[state], pi[state]))
# ---> 39         input()
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
